# %%
# Implementation of Binary Search
# Time Complexity : O(logn)
# Function Defination
def binarySearch(arr, i, j, x):
    while i<=j:
        mid = i + (j-i) // 2
        if arr[mid] == x:
            return mid
        
        elif arr[mid] > x:
            # recursion calling the same function again with different set of parameters
            return binarySearch(arr, i, mid-1, x)
        
        else:
            # recursion calling the same function again with different set of parameters
            return binarySearch(arr, mid+1, j, x)
    return -1
# Driver Code
# Sorted Array
arr = [2, 5, 10, 14, 18, 22, 27, 35, 40, 59]
x = 10
i = 0
j =len(arr) - 1
# Function Call
result = binarySearch(arr, i, j, x)
print(f"Searching fo element {x} is present at index {result}")
# Out:
# Searching fo element 10 is present at index 2

# %%
# Without While Loop
def binarySearch(arr, i, j, x):
    if i > j:
        return -1
    mid = i + (j - i) // 2
    if arr[mid] == x:
        return mid
    elif arr[mid] > x:
        return binarySearch(arr, i, mid - 1, x)
    else:
        return binarySearch(arr, mid + 1, j, x)
    
    # Driver Code
# Sorted Array
arr = [2, 5, 10, 14, 18, 22, 27, 35, 40, 59]
x = 22
i = 0
j =len(arr) - 1
# Function Call
result = binarySearch(arr, i, j, x)
print(f"Searching fo element {x} is present at index {result}")
# Out:
# Searching fo element 22 is present at index 5

# %%
# Implementation of Binary Search without Recursion
# Function Defination
def binarySearch(arr, i, j, x):
    while i<=j:
        mid = i + (j-i) // 2
        if arr[mid] == x:
            return mid
        
        elif arr[mid] > x: #update the j paramenter
            j = mid -1
         
        else:
            i = mid + 1 #update the i paramenter
    return -1 
# Driver Code
# Sorted Array
arr = [2, 5, 10, 14, 18, 22, 27, 35, 40, 59]
x = 10
i = 0
j =len(arr) - 1
# Function Call
result = binarySearch(arr, i, j, x)
print(f"Searching fo element {x} is present at index {result}")
# Out:
# Searching fo element 10 is present at index 2
