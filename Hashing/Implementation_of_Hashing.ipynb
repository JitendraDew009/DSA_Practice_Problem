# %%
hash_list = [['A', 0],['B', 1], ['C',2], ['D', 3], ['E', 4]]
hash_list
# Out:
# [['A', 0], ['B', 1], ['C', 2], ['D', 3], ['E', 4]]

# %%
hash_list[4]
# Out:
# ['E', 4]

# %%
# Time complexity: O(n)
for record in hash_list:
    if record[0] == 'E':
        print(record[1])
# Out:
# 4

# %%
# Dictionary is most optimized way to store the data
hash_list = [['A', 0],['B', 1], ['C',2], ['D', 3], ['E', 4]]

hash_table = {}

for record in hash_list:
   hash_table[record[0]] = record[1]

print(hash_table)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4}

# %%
# Alternate and fastest way
hash_table = dict(hash_list)

# %%
hash_table
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4}

# %%
# Time complexity : O(1)
print(hash_table['A'])
print(hash_table['B'])
print(hash_table['C'])
print(hash_table['D'])
print(hash_table['E'])
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# ord function in python returns the ASCII value of every characcter.
print(ord("A"))
print(ord("B"))
print(ord("C"))
print(ord("D"))
# Out:
# 65
# 66
# 67
# 68

# %%
# Modulo function
def get_hash(self, key):
    hash = 0
    for char in key:
        # ord function in pyhton helps us to get ascii value of any character 
        hash += ord(char)
    return hash % self.MAX

# %%
class HashTable:
    def __init__(self):
        self.MAX = 10
        # list Comprehension
        self.arr = [None for i in range(self.MAX)]

        # Method to calculate the hash function for a given value

        def get_hash(self, key):
            hash = 0
         
            for char in key:
                # ord function in pyhton helps us to get ascii value of any character 
                hash += ord(char)
            return hash % self.MAX
        
        # Method defination of standard operators as fucntion in python
        # getitem - to fetch the value of the given index inside hash table
        def __getitem__(self, index):
            h = self.get_hash(index)
            return self.arr[h]
        
        # setitem - to set the value corresponding to key inside hash table
        def __setitem__(self, key, val):
            h = self.get_hash(key)
            self.arr[h] = val

        #  delitem - to delete the values inside the hash table for a given key
        def __delitem__(self, key):
            h = self.get_hash(key)
            self.arr[h] = None


# Driver code

h = HashTable()

h["A"] = 12
h["B"] = 32
# h["C"] = 14
# h["D"] = 52
# h["E"] = 16
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 38
#      34 # Driver code
#      36 h = HashTable()
# ---> 38 h["A"] = 12
#      39 h["B"] = 32
#      40 # h["C"] = 14
#      41 # h["D"] = 52
#      42 # h["E"] = 16
#
# TypeError: 'HashTable' object does not support item assignment

# %%
h.arr
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
h["A"] = 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 h["A"] = 12
#
# TypeError: 'HashTable' object does not support item assignment

# %%
class HashTable:
    def __init__(self):
        self.MAX = 10
        # list comprehension to initialize array
        self.arr = [None for i in range(self.MAX)]

    # Method to calculate the hash function for a given value
    def get_hash(self, key):
        hash = 0
        for char in key:
            # ord function in Python helps us to get ASCII value of any character
            hash += ord(char)
        return hash % self.MAX

    # getitem - to fetch the value of the given index inside hash table
    def __getitem__(self, index):
        h = self.get_hash(index)
        return self.arr[h]

    # setitem - to set the value corresponding to key inside hash table
    def __setitem__(self, key, val):
        h = self.get_hash(key)
        self.arr[h] = val

    # delitem - to delete the values inside the hash table for a given key
    def __delitem__(self, key):
        h = self.get_hash(key)
        self.arr[h] = None


# Driver code
h = HashTable()
h["A"] = 12
h["B"] = 32

print(h["A"])  # 12
print(h["B"])  # 32
# Out:
# 12
# 32

# %%
h.arr
# Out:
# [None, None, None, None, None, 12, 32, None, None, None]

# %%
h.get_hash("A")
# Out:
# 5

# %%
h.get_hash("B")
# Out:
# 6

# %%
h.get_hash("C")
# Out:
# 7

# %%
h.get_hash("D")
# Out:
# 8

# %%
h["A"] = 13
h["B"] = 31

print(h["A"])
print(h["B"])
# Out:
# 13
# 31

# %%
# A B both contains the same key. So, value overrides here. This is the concept of Collision in Hashing.
h.arr
# Out:
# [None, None, None, None, None, 13, 31, None, None, None]
