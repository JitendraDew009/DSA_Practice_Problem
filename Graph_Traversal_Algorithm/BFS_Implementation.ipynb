# %%
# Time complexity : O(V+E)
# Required Data structure - Queue
# Application: whether the graph is connected or not
from collections import deque
queue = deque()

#function defination
# queue - FIFO (append.left and pop) or (append and popleft)

def breadthFirstTraversal(visted, graph, node):
    visited.add(node)
    queue.appendleft(node)

    while queue:
        node = queue.pop()
        print(node, end= " ")

        for adjacentNodes in graph[node]:
            if adjacentNodes not in visited:
                visited.add(adjacentNodes)
                queue.appendleft(adjacentNodes)

# Driver code
visited = set()

# storing the graph in the form of adjacency list
graph = {
    'A' : ['B', 'C', 'D'],
    'B' : ['E'],
    'C' : ['E', 'F'],
    'D' : ['F'],
    'E' : ['G'],
    'F' : ['G'],
    'G' : []

}

# function calling
print("Breadth_First_Traversal:")
breadthFirstTraversal(visited, graph, 'A')
# Out:
# Breadth_First_Traversal:
# A B C D E F G

# %% [raw]
# Applications:
# 1. shorest path in Unweighted graph
# 2. web crawlers
# 3. social networking sites
# 4. GPS navigation systems
# 5. Network Broadcasting
# 6. Peer-to-Peer Networks: system like BitTorrents use BFS to discover and connect with neighboring peer nodes
# 7. Cycle detection: BFS can check for cycles in undirected graphs
# 8. Testing Bipartiteness: BFS helps determine if a graph can be colored using two colors such that no ttwo adjacent nodes share the same color.
