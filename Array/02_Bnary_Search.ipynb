# %%
## Implementation of Binary Search using recursion
def binarySearch(arr, i, j, x):
    while i <= j:
        mid = i + (j - i) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            return binarySearch(arr, mid+1, j, x) # recursion -> caliing the same function again 
                                                  # with different set of parameters
        else:
            return binarySearch(arr, i, mid-1, x)
    return -1


## Driver_Code
## Sorted array
arr = [2,5,10,14,18,22,27,35,40,59]
x = 40
i = 0
j = len(arr) - 1
result = binarySearch(arr, i, j, x)
print("Seaching element is present at index", result)
# Out:
# Seaching element is present at index 8

# %%
## Implementation of Binary Search using recursion
def binarySearch(arr, i, j, x):
    while i <= j:
        mid = i + (j - i) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            return binarySearch(arr, mid+1, j, x)
        else:
            return binarySearch(arr, i, mid-1, x)
    return -1


## Driver_Code
## Sorted array
arr = [2,5,10,14,18,22,27,35,40,59]
x = 20
i = 0
j = len(arr) - 1
result = binarySearch(arr, i, j, x)
print("Seaching element is present at index", result)
# Out:
# Seaching element is present at index -1

# %%
## Implementation of Binary Search using recursion
def binarySearch(arr, i, j, x):
    while i <= j:
        mid = i + (j - i) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            return binarySearch(arr, mid+1, j, x)
        else:
            return binarySearch(arr, i, mid-1, x)
    return -1


## Driver_Code
## Sorted array
arr = [2,5,10,14,18,22,27,35,40,59]
x = 59
i = 0
j = len(arr) - 1
result = binarySearch(arr, i, j, x)
print("Seaching element is present at index", result)
# Out:
# Seaching element is present at index 9

# %%
## Implementation of Binary Search WITHOUT using recursion
def binarySearch(arr, i, j, x):
    while i <= j:
        mid = i + (j - i) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            ## update the i parameter
            i = mid + 1
            
        else:
           ## update the j parameter
            j = mid - 1
    return -1


## Driver_Code
## Sorted array
arr = [2,5,10,14,18,22,27,35,40,59]
x = 59
i = 0
j = len(arr) - 1
result = binarySearch(arr, i, j, x)
print("Seaching element is present at index", result)
# Out:
# Seaching element is present at index 9

# %% [raw]
# Time complexity of Binary Search :
# 1. mid == x then O(1)
# 2. arr[mid] < x then O(logn)
# 3. arr[mid] > x then aslo O(logn)
