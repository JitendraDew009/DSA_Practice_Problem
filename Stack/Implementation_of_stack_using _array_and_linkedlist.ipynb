# %%
# Implementation of stack using array data structure
# append -> pushing the data inside the stack
stack = []
stack.append(0)
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
# |------------------------|
# |          4             |
# |          3             |
# |          2             |
# |          1             |
# |          0             |
# |------------------------|

stack
# Out:
# [0, 1, 2, 3, 4]

# %%
# pop the data from the stack
stack.pop()
# Out:
# 4

# %%
stack.pop()
# Out:
# 3

# %%
stack
# Out:
# [0, 1, 2]

# %%
# peek function inside the stack data structure
stack[-1]
# Out:
# 2

# %%
stack
# Out:
# [0, 1, 2]

# %%
stack.pop()
# Out:
# 2

# %%
stack.pop()
# Out:
# 1

# %%
stack.pop()
# Out:
# 0

# %%
stack.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 stack.pop()
#
# IndexError: pop from empty list

# %%
# Implementation of stack using circular deque
from collections import deque
stack = deque()

stack.append(0)
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)

# %%
dir(stack)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
stack
# Out:
# deque([0, 1, 2, 3, 4])

# %%
stack.pop()
# Out:
# 4

# %%
stack.pop()
# Out:
# 3

# %%
# You can create your own class and define all the function as well.
class Stack:
    def __init__(self):
        self.data = deque()

    # insertion element inside the stack data structure
    def push(self, data):
        self.data.append(data)

    # deletion last element inside the stack data structure

    def pop(self):
        return self.data.pop()
    
    # last element inside the stack data structure

    def peek(self):
        return self.data[-1]
    
    # size of the stack
    def size(self):
        return len(self.data)
    
    # to check whether the stack is empty or not
    def isEmpty(self): 
        return len(self.data) == 0

# %%
s = Stack()
s.push(15)
s.push(12)
s.push(11)
s.push(9)
s.push(6)
s.push(5)
s.push(3)

# %%
s.peek()
# Out:
# 3

# %%
s.size()
# Out:
# 7

# %%
s.pop()
# Out:
# 3

# %%
s.size()
# Out:
# 6

# %%
s.isEmpty()
# Out:
# False
